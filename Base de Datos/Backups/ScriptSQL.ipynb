-- %% [markdown]
-- # [A2BankibgDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [A2BankibgDB]    Script Date: 31/3/2026 10:04:07 ******/
CREATE DATABASE [A2BankibgDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'A2BankibgDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\A2BankibgDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'A2BankibgDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\A2BankibgDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [A2BankibgDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [A2BankibgDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [A2BankibgDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [A2BankibgDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [A2BankibgDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [A2BankibgDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [A2BankibgDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [A2BankibgDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [A2BankibgDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [A2BankibgDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [A2BankibgDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [A2BankibgDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [A2BankibgDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [A2BankibgDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [A2BankibgDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [A2BankibgDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [A2BankibgDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [A2BankibgDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [A2BankibgDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [A2BankibgDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [A2BankibgDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [A2BankibgDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [A2BankibgDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [A2BankibgDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [A2BankibgDB] SET RECOVERY FULL 
GO
ALTER DATABASE [A2BankibgDB] SET  MULTI_USER 
GO
ALTER DATABASE [A2BankibgDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [A2BankibgDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [A2BankibgDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [A2BankibgDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [A2BankibgDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [A2BankibgDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'A2BankibgDB', N'ON'
GO
ALTER DATABASE [A2BankibgDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [A2BankibgDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Rol]

-- %%
USE [A2BankibgDB]
GO

-- %%
/****** Object:  Table [dbo].[Rol]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rol](
	[RolId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
	[Descripcion] [nvarchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[RolId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[UsuarioId] [int] IDENTITY(1,1) NOT NULL,
	[RolId] [int] NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[NombreUsuario] [nvarchar](50) NOT NULL,
	[Contrasena] [nvarchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UsuarioId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vwListaUsuarios]

-- %%
/****** Object:  View [dbo].[vwListaUsuarios]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create view [dbo].[vwListaUsuarios]
with schemabinding
as
select a.UsuarioId, r.Nombre as Rol, a.Nombre, a.NombreUsuario, a.Contrasena
from dbo.Usuario as a
inner join dbo.Rol as r on a.RolId = r.RolId
GO

-- %% [markdown]
-- # [dbo].[Banco]

-- %%
/****** Object:  Table [dbo].[Banco]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Banco](
	[BancoId] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Descripcion] [nvarchar](200) NULL,
	[Ubicacion] [nvarchar](200) NULL,
	[ComisionId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[BancoId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estado]

-- %%
/****** Object:  Table [dbo].[Estado]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estado](
	[EstadoID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
	[Descripcion] [nvarchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[EstadoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Titular]

-- %%
/****** Object:  Table [dbo].[Titular]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Titular](
	[TitularId] [int] NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Edad] [int] NULL,
	[Sexo] [char](1) NULL,
	[Ocupacion] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[TitularId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cuenta]

-- %%
/****** Object:  Table [dbo].[Cuenta]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cuenta](
	[CuentaId] [int] IDENTITY(1,1) NOT NULL,
	[BancoId] [int] NOT NULL,
	[NumeroCuenta] [int] NOT NULL,
	[TitularId] [int] NOT NULL,
	[Balance] [decimal](18, 2) NOT NULL,
	[FechaCreacion] [date] NOT NULL,
	[EstadoId] [int] NOT NULL,
	[CodigoPin] [nvarchar](10) NULL,
	[CodigoHuella] [varbinary](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[CuentaId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vwListaCuenta]

-- %%
/****** Object:  View [dbo].[vwListaCuenta]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create view [dbo].[vwListaCuenta]
with schemabinding
as
select c.CuentaId, b.Nombre as Banco, c.NumeroCuenta,
c.TitularId, t.Nombre as Nombre, c.Balance, c.FechaCreacion, 
e.Nombre as Estado, c.CodigoPin, c.CodigoHuella
from dbo.Cuenta as c
inner join dbo.Banco as b on c.BancoId = b.BancoId
inner join dbo.Titular as t on c.TitularId = t.TitularId
inner join dbo.Estado as e on c.EstadoId = e.EstadoID
GO

-- %% [markdown]
-- # [dbo].[Comision]

-- %%
/****** Object:  Table [dbo].[Comision]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comision](
	[ComisionId] [int] IDENTITY(1,1) NOT NULL,
	[Cantidad] [decimal](5, 4) NOT NULL,
	[Descripcion] [nvarchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[ComisionId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Deposito]

-- %%
/****** Object:  Table [dbo].[Deposito]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Deposito](
	[DepositoId] [int] IDENTITY(1,1) NOT NULL,
	[CuentaId] [int] NOT NULL,
	[ClienteId] [int] NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
	[Fecha] [datetime] NOT NULL,
	[Cantidad] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK__Deposito__345C2198F8BF891C] PRIMARY KEY CLUSTERED 
(
	[DepositoId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Retiro]

-- %%
/****** Object:  Table [dbo].[Retiro]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Retiro](
	[RetiroId] [int] IDENTITY(1,1) NOT NULL,
	[CuentaId] [int] NOT NULL,
	[ClienteId] [int] NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
	[Fecha] [datetime] NOT NULL,
	[Cantidad] [decimal](18, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[RetiroId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Transferencia]

-- %%
/****** Object:  Table [dbo].[Transferencia]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Transferencia](
	[TransferenciaId] [int] IDENTITY(1,1) NOT NULL,
	[CuentaOrigenId] [int] NOT NULL,
	[CuentaDestinoId] [int] NOT NULL,
	[Monto] [decimal](18, 2) NOT NULL,
	[Comision] [decimal](18, 2) NOT NULL,
	[Fecha] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[TransferenciaId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Banco]

-- %%
SET IDENTITY_INSERT [dbo].[Banco] ON 
INSERT [dbo].[Banco] ([BancoId], [Nombre], [Descripcion], [Ubicacion], [ComisionId]) VALUES (1, N'A2 Banking', N'Banco nacional de springfield', N'springfield', 1)
SET IDENTITY_INSERT [dbo].[Banco] OFF
GO

-- %% [markdown]
-- # [dbo].[Comision]

-- %%
SET IDENTITY_INSERT [dbo].[Comision] ON 
INSERT [dbo].[Comision] ([ComisionId], [Cantidad], [Descripcion]) VALUES (1, CAST(0.0150 AS Decimal(5, 4)), N'Tarifa del 0.15% para transferencias entre bancos diferentes')
SET IDENTITY_INSERT [dbo].[Comision] OFF
GO

-- %% [markdown]
-- # [dbo].[Cuenta]

-- %%
SET IDENTITY_INSERT [dbo].[Cuenta] ON 
INSERT [dbo].[Cuenta] ([CuentaId], [BancoId], [NumeroCuenta], [TitularId], [Balance], [FechaCreacion], [EstadoId], [CodigoPin], [CodigoHuella]) VALUES (2, 1, 100000001, 1, CAST(5400.00 AS Decimal(18, 2)), CAST(N'2026-03-24' AS Date), 1, N'1234', ...)
INSERT [dbo].[Cuenta] ([CuentaId], [BancoId], [NumeroCuenta], [TitularId], [Balance], [FechaCreacion], [EstadoId], [CodigoPin], [CodigoHuella]) VALUES (3, 1, 100000002, 2, CAST(6750.00 AS Decimal(18, 2)), CAST(N'2026-03-26' AS Date), 1, N'12345', ...)
INSERT [dbo].[Cuenta] ([CuentaId], [BancoId], [NumeroCuenta], [TitularId], [Balance], [FechaCreacion], [EstadoId], [CodigoPin], [CodigoHuella]) VALUES (4, 1, 100000003, 17, CAST(5785.00 AS Decimal(18, 2)), CAST(N'2026-03-26' AS Date), 1, N'1212', ...)
INSERT [dbo].[Cuenta] ([CuentaId], [BancoId], [NumeroCuenta], [TitularId], [Balance], [FechaCreacion], [EstadoId], [CodigoPin], [CodigoHuella]) VALUES (5, 1, 100000004, 26, CAST(8500.00 AS Decimal(18, 2)), CAST(N'2026-03-26' AS Date), 1, N'1221', ...)
SET IDENTITY_INSERT [dbo].[Cuenta] OFF
GO

-- %% [markdown]
-- # [dbo].[Deposito]

-- %%
SET IDENTITY_INSERT [dbo].[Deposito] ON 
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (1, 2, 1, N'Homer Simpson', CAST(N'2026-03-25T00:00:00.000' AS DateTime), CAST(500.00 AS Decimal(18, 2)))
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (3, 2, 1, N'Homer Simpson', CAST(N'2026-03-25T00:00:00.000' AS DateTime), CAST(550.00 AS Decimal(18, 2)))
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (5, 2, 9, N'Ned Flanders', CAST(N'2026-03-25T00:00:00.000' AS DateTime), CAST(1000.00 AS Decimal(18, 2)))
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (6, 5, 9, N'Ned Flanders', CAST(N'2026-03-26T00:00:00.000' AS DateTime), CAST(2500.00 AS Decimal(18, 2)))
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (7, 4, 21, N'Otto Mann', CAST(N'2026-03-26T00:00:00.000' AS DateTime), CAST(785.00 AS Decimal(18, 2)))
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (8, 3, 2, N'Marge Simpson', CAST(N'2026-03-26T00:00:00.000' AS DateTime), CAST(1750.00 AS Decimal(18, 2)))
INSERT [dbo].[Deposito] ([DepositoId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (9, 5, 1, N'Homer Simpson', CAST(N'2026-03-26T00:00:00.000' AS DateTime), CAST(1000.00 AS Decimal(18, 2)))
SET IDENTITY_INSERT [dbo].[Deposito] OFF
GO

-- %% [markdown]
-- # [dbo].[Estado]

-- %%
SET IDENTITY_INSERT [dbo].[Estado] ON 
INSERT [dbo].[Estado] ([EstadoID], [Nombre], [Descripcion]) VALUES (1, N'Activa', N'Cuenta activa, se puede usar con normalidad')
INSERT [dbo].[Estado] ([EstadoID], [Nombre], [Descripcion]) VALUES (2, N'Inactiva', N'Cuenta inactiva, no se puede usar')
INSERT [dbo].[Estado] ([EstadoID], [Nombre], [Descripcion]) VALUES (3, N'Cancelada', N'La cuenta a sigo cancelada permanentemente')
SET IDENTITY_INSERT [dbo].[Estado] OFF
GO

-- %% [markdown]
-- # [dbo].[Retiro]

-- %%
SET IDENTITY_INSERT [dbo].[Retiro] ON 
INSERT [dbo].[Retiro] ([RetiroId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (1, 2, 1, N'Homer Simpson', CAST(N'2026-03-25T00:00:00.000' AS DateTime), CAST(500.00 AS Decimal(18, 2)))
INSERT [dbo].[Retiro] ([RetiroId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (2, 2, 1, N'Homer Simpson', CAST(N'2026-03-25T00:00:00.000' AS DateTime), CAST(750.00 AS Decimal(18, 2)))
INSERT [dbo].[Retiro] ([RetiroId], [CuentaId], [ClienteId], [Nombre], [Fecha], [Cantidad]) VALUES (3, 2, 1, N'Homer Simpson', CAST(N'2026-03-26T00:00:00.000' AS DateTime), CAST(400.00 AS Decimal(18, 2)))
SET IDENTITY_INSERT [dbo].[Retiro] OFF
GO

-- %% [markdown]
-- # [dbo].[Rol]

-- %%
SET IDENTITY_INSERT [dbo].[Rol] ON 
INSERT [dbo].[Rol] ([RolId], [Nombre], [Descripcion]) VALUES (1, N'Administrador General', N'Personal encargado del sistema bancario')
INSERT [dbo].[Rol] ([RolId], [Nombre], [Descripcion]) VALUES (2, N'Encargado/a de Retiros', N'Personal que realiza los retiros de las cuentas')
INSERT [dbo].[Rol] ([RolId], [Nombre], [Descripcion]) VALUES (3, N'Encargado/a de caja', N'Personal que atiente a los clientes en caja')
INSERT [dbo].[Rol] ([RolId], [Nombre], [Descripcion]) VALUES (4, N'Encargado/a de Depósitos', N'Personal que realiza los depositos de las cuentas')
SET IDENTITY_INSERT [dbo].[Rol] OFF
GO

-- %% [markdown]
-- # [dbo].[Titular]

-- %%
INSERT [dbo].[Titular] ([TitularId], [Nombre], [Edad], [Sexo], [Ocupacion]) VALUES (1, N'Homer Simpson', 39, N'M', N'Safety Inspector')
INSERT [dbo].[Titular] ([TitularId], [Nombre], [Edad], [Sexo], [Ocupacion]) VALUES (2, N'Marge Simpson', 39, N'F', N'Unemployed')
INSERT [dbo].[Titular] ([TitularId], [Nombre], [Edad], [Sexo], [Ocupacion]) VALUES (17, N'Apu Nahasapeemapetilon', 47, N'M', N'Owner of the Kwik-E-Mart')
INSERT [dbo].[Titular] ([TitularId], [Nombre], [Edad], [Sexo], [Ocupacion]) VALUES (26, N'Barney Gumble', 39, N'M', N'Helicopter pilot')
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
SET IDENTITY_INSERT [dbo].[Usuario] ON 
INSERT [dbo].[Usuario] ([UsuarioId], [RolId], [Nombre], [NombreUsuario], [Contrasena]) VALUES (1, 1, N'Halveys', N'sa', N'sa')
INSERT [dbo].[Usuario] ([UsuarioId], [RolId], [Nombre], [NombreUsuario], [Contrasena]) VALUES (2, 3, N'Manuel', N'ma', N'ma')
INSERT [dbo].[Usuario] ([UsuarioId], [RolId], [Nombre], [NombreUsuario], [Contrasena]) VALUES (3, 4, N'Humberto', N'hj', N'hj')
SET IDENTITY_INSERT [dbo].[Usuario] OFF
GO

-- %% [markdown]
-- # [UQ__Cuenta__E039507BC6A9E2D6]

-- %%
/****** Object:  Index [UQ__Cuenta__E039507BC6A9E2D6]    Script Date: 31/3/2026 10:04:08 ******/
ALTER TABLE [dbo].[Cuenta] ADD UNIQUE NONCLUSTERED 
(
	[NumeroCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__Usuario__E3237CF706CFCD8B]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Usuario__E3237CF706CFCD8B]    Script Date: 31/3/2026 10:04:08 ******/
ALTER TABLE [dbo].[Usuario] ADD UNIQUE NONCLUSTERED 
(
	[NombreUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Cuenta__Balance__46E78A0C]

-- %%
ALTER TABLE [dbo].[Cuenta] ADD  DEFAULT ((0)) FOR [Balance]
GO

-- %% [markdown]
-- # [DF__Cuenta__FechaCre__47DBAE45]

-- %%
ALTER TABLE [dbo].[Cuenta] ADD  DEFAULT (getdate()) FOR [FechaCreacion]
GO

-- %% [markdown]
-- # [DF__Deposito__Fecha__4D94879B]

-- %%
ALTER TABLE [dbo].[Deposito] ADD  CONSTRAINT [DF__Deposito__Fecha__4D94879B]  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__Retiro__Fecha__7F2BE32F]

-- %%
ALTER TABLE [dbo].[Retiro] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__Transfere__Comis__5535A963]

-- %%
ALTER TABLE [dbo].[Transferencia] ADD  DEFAULT ((0)) FOR [Comision]
GO

-- %% [markdown]
-- # [DF__Transfere__Fecha__5629CD9C]

-- %%
ALTER TABLE [dbo].[Transferencia] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [FK_Banco_Comision]

-- %%
ALTER TABLE [dbo].[Banco]  WITH CHECK ADD  CONSTRAINT [FK_Banco_Comision] FOREIGN KEY([ComisionId])
REFERENCES [dbo].[Comision] ([ComisionId])
GO
ALTER TABLE [dbo].[Banco] CHECK CONSTRAINT [FK_Banco_Comision]
GO

-- %% [markdown]
-- # [FK_Cuenta_Banco]

-- %%
ALTER TABLE [dbo].[Cuenta]  WITH CHECK ADD  CONSTRAINT [FK_Cuenta_Banco] FOREIGN KEY([BancoId])
REFERENCES [dbo].[Banco] ([BancoId])
GO
ALTER TABLE [dbo].[Cuenta] CHECK CONSTRAINT [FK_Cuenta_Banco]
GO

-- %% [markdown]
-- # [FK_Cuenta_Estado]

-- %%
ALTER TABLE [dbo].[Cuenta]  WITH CHECK ADD  CONSTRAINT [FK_Cuenta_Estado] FOREIGN KEY([EstadoId])
REFERENCES [dbo].[Estado] ([EstadoID])
GO
ALTER TABLE [dbo].[Cuenta] CHECK CONSTRAINT [FK_Cuenta_Estado]
GO

-- %% [markdown]
-- # [FK_Cuenta_Titular]

-- %%
ALTER TABLE [dbo].[Cuenta]  WITH CHECK ADD  CONSTRAINT [FK_Cuenta_Titular] FOREIGN KEY([TitularId])
REFERENCES [dbo].[Titular] ([TitularId])
GO
ALTER TABLE [dbo].[Cuenta] CHECK CONSTRAINT [FK_Cuenta_Titular]
GO

-- %% [markdown]
-- # [FK_Deposito_Cuenta]

-- %%
ALTER TABLE [dbo].[Deposito]  WITH CHECK ADD  CONSTRAINT [FK_Deposito_Cuenta] FOREIGN KEY([CuentaId])
REFERENCES [dbo].[Cuenta] ([CuentaId])
GO
ALTER TABLE [dbo].[Deposito] CHECK CONSTRAINT [FK_Deposito_Cuenta]
GO

-- %% [markdown]
-- # [FK_Retiro_Cuenta]

-- %%
ALTER TABLE [dbo].[Retiro]  WITH CHECK ADD  CONSTRAINT [FK_Retiro_Cuenta] FOREIGN KEY([CuentaId])
REFERENCES [dbo].[Cuenta] ([CuentaId])
GO
ALTER TABLE [dbo].[Retiro] CHECK CONSTRAINT [FK_Retiro_Cuenta]
GO

-- %% [markdown]
-- # [FK_Transferencia_Destino]

-- %%
ALTER TABLE [dbo].[Transferencia]  WITH CHECK ADD  CONSTRAINT [FK_Transferencia_Destino] FOREIGN KEY([CuentaDestinoId])
REFERENCES [dbo].[Cuenta] ([NumeroCuenta])
GO
ALTER TABLE [dbo].[Transferencia] CHECK CONSTRAINT [FK_Transferencia_Destino]
GO

-- %% [markdown]
-- # [FK_Transferencia_Origen]

-- %%
ALTER TABLE [dbo].[Transferencia]  WITH CHECK ADD  CONSTRAINT [FK_Transferencia_Origen] FOREIGN KEY([CuentaOrigenId])
REFERENCES [dbo].[Cuenta] ([NumeroCuenta])
GO
ALTER TABLE [dbo].[Transferencia] CHECK CONSTRAINT [FK_Transferencia_Origen]
GO

-- %% [markdown]
-- # [FK_Usuario_Rol]

-- %%
ALTER TABLE [dbo].[Usuario]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Rol] FOREIGN KEY([RolId])
REFERENCES [dbo].[Rol] ([RolId])
GO
ALTER TABLE [dbo].[Usuario] CHECK CONSTRAINT [FK_Usuario_Rol]
GO

-- %% [markdown]
-- # [CHK_Cantidad]

-- %%
ALTER TABLE [dbo].[Deposito]  WITH CHECK ADD  CONSTRAINT [CHK_Cantidad] CHECK  (([Cantidad]>(0)))
GO
ALTER TABLE [dbo].[Deposito] CHECK CONSTRAINT [CHK_Cantidad]
GO

-- %% [markdown]
-- # [CHK_CantidadRetiro]

-- %%
ALTER TABLE [dbo].[Retiro]  WITH CHECK ADD  CONSTRAINT [CHK_CantidadRetiro] CHECK  (([Cantidad]>(0)))
GO
ALTER TABLE [dbo].[Retiro] CHECK CONSTRAINT [CHK_CantidadRetiro]
GO

-- %% [markdown]
-- # [dbo].[spActualizarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[spActualizarUsuario]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spActualizarUsuario]
    @UsuarioId   INT,
    @RolId       INT,
    @Nombre      NVARCHAR(100),
    @NombreUsuario NVARCHAR(50),
    @Contrasena  NVARCHAR(255)
AS
BEGIN
    SET NOCOUNT ON;

    UPDATE Usuario
    SET
        RolId          = @RolId,
        Nombre         = @Nombre,
        NombreUsuario  = @NombreUsuario,
        Contrasena     = @Contrasena
    WHERE UsuarioId = @UsuarioId
END
GO

-- %% [markdown]
-- # [dbo].[spAgregarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[spAgregarUsuario]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spAgregarUsuario]
    @RolId       INT,
    @Nombre      NVARCHAR(100),
    @NombreUsuario NVARCHAR(50),
    @Contrasena  NVARCHAR(255)
AS
BEGIN
    SET NOCOUNT ON;

    INSERT INTO Usuario (RolId, Nombre, NombreUsuario, Contrasena)
    VALUES (@RolId, @Nombre, @NombreUsuario, @Contrasena)
END
GO

-- %% [markdown]
-- # [dbo].[spCrearCuenta]

-- %%
/****** Object:  StoredProcedure [dbo].[spCrearCuenta]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spCrearCuenta]
    @BancoId       INT,
    @NumeroCuenta  INT,
    @TitularId     INT,
    @Balance       DECIMAL(18,2),
    @FechaCreacion DATE,
    @EstadoId      INT,
    @CodigoPin     NVARCHAR(10),
    @CodigoHuella  VARBINARY(MAX)
AS
BEGIN
    SET NOCOUNT ON;

    INSERT INTO Cuenta (
        BancoId,
        NumeroCuenta,
        TitularId,
        Balance,
        FechaCreacion,
        EstadoId,
        CodigoPin,
        CodigoHuella
    )
    VALUES (
        @BancoId,
        @NumeroCuenta,
        @TitularId,
        @Balance,
        @FechaCreacion,
        @EstadoId,
        @CodigoPin,
        @CodigoHuella
    );

END;
GO

-- %% [markdown]
-- # [dbo].[spCuentaExiste]

-- %%
/****** Object:  StoredProcedure [dbo].[spCuentaExiste]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create   proc [dbo].[spCuentaExiste]
(
@NumeroCuenta int,
@CodigoPin int
)
as
set nocount on
begin
select c.NumeroCuenta, c.Balance, t.Nombre from Cuenta as c
inner join Titular as t on c.TitularId = t.TitularId
where (NumeroCuenta = @NumeroCuenta and CodigoPin = @CodigoPin) and EstadoId = 1
end
GO

-- %% [markdown]
-- # [dbo].[spDepositarBalanceCuenta]

-- %%
/****** Object:  StoredProcedure [dbo].[spDepositarBalanceCuenta]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create   proc [dbo].[spDepositarBalanceCuenta]
(
@NumeroCuenta int,
@ClienteId int,
@Nombre nvarchar(50),
@Balance decimal(18,2),
@Fecha date
)
as
set nocount on
begin
    begin try
        begin tran
            declare @CuentaId int

            set @CuentaId = (select CuentaId from Cuenta where NumeroCuenta = @NumeroCuenta)

            insert into Deposito values (@CuentaId, @ClienteId, @Nombre, @Fecha, @Balance)

            declare @NewBalance decimal(18,2)

            set @NewBalance = (select Balance from Cuenta where NumeroCuenta = @NumeroCuenta) + @Balance

            update Cuenta set Balance = @NewBalance where NumeroCuenta = @NumeroCuenta
        commit tran
    end try
    begin catch
        rollback tran
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spExisteUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[spExisteUsuario]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create   proc [dbo].[spExisteUsuario]
(
@NombreUsuario NVARCHAR(100),
@Contrasena NVARCHAR(50)
)
as
set nocount on
begin
declare @RolId int = 0
select @RolId = ISNULL(RolId, 0) from usuario where NombreUsuario = @NombreUsuario and Contrasena = @Contrasena
SELECT @RolId
end
GO

-- %% [markdown]
-- # [dbo].[spInsertarTitular]

-- %%
/****** Object:  StoredProcedure [dbo].[spInsertarTitular]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[spInsertarTitular]
(
@TitularId int,
@Nombre nvarchar(100),
@Edad int,
@Sexo char(1),
@Ocupacion nvarchar(100)
)
as
set nocount on
begin
insert into Titular select @TitularId, @Nombre, @Edad, @Sexo, @Ocupacion
end
GO

-- %% [markdown]
-- # [dbo].[spListaCuentas]

-- %%
/****** Object:  StoredProcedure [dbo].[spListaCuentas]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[spListaCuentas]
as 
set nocount on
begin
select * from vwListaCuenta
end
GO

-- %% [markdown]
-- # [dbo].[spNumeroCuenta]

-- %%
/****** Object:  StoredProcedure [dbo].[spNumeroCuenta]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[spNumeroCuenta]
as
set nocount on
begin
select isnull(max(NumeroCuenta), 100000000) + 1
from Cuenta 
end
GO

-- %% [markdown]
-- # [dbo].[spRetirarBalanceCuenta]

-- %%
/****** Object:  StoredProcedure [dbo].[spRetirarBalanceCuenta]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create   proc [dbo].[spRetirarBalanceCuenta]
(
@NumeroCuenta int,
@ClienteId int,
@Nombre nvarchar(50),
@Balance decimal(18,2),
@Fecha date
)
as
set nocount on
begin
    begin try
        begin tran
            declare @CuentaId int

            set @CuentaId = (select CuentaId from Cuenta where NumeroCuenta = @NumeroCuenta)

            insert into Retiro values (@CuentaId, @ClienteId, @Nombre, @Fecha, @Balance)

            declare @NewBalance decimal(18,2)

            set @NewBalance = (select Balance from Cuenta where NumeroCuenta = @NumeroCuenta) - @Balance

            update Cuenta set Balance = @NewBalance where NumeroCuenta = @NumeroCuenta
        commit tran
    end try
    begin catch
        rollback tran
    end catch
end
GO

-- %% [markdown]
-- # [dbo].[spVerRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[spVerRoles]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[spVerRoles]
as
set nocount on
begin
select RolId, Nombre, Descripcion from Rol
end
GO

-- %% [markdown]
-- # [dbo].[spVerTitulares]

-- %%
/****** Object:  StoredProcedure [dbo].[spVerTitulares]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[spVerTitulares]
as
set nocount on
begin
select TitularId, Nombre, Edad, Sexo, Ocupacion from Titular
end
GO

-- %% [markdown]
-- # [dbo].[spVerUsuarios]

-- %%
/****** Object:  StoredProcedure [dbo].[spVerUsuarios]    Script Date: 31/3/2026 10:04:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[spVerUsuarios]
as 
set nocount on
begin
select * from vwListaUsuarios
end
GO

-- %% [markdown]
-- # [A2BankibgDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [A2BankibgDB] SET  READ_WRITE 
GO
